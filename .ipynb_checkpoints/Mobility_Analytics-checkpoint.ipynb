# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns',None)

# %%
train = pd.read_csv('train_Wc8LBpr.csv')
test = pd.read_csv('test_VsU9xXK.csv')
sample = pd.read_csv('sample_submission_NoPBkjr.csv')

# %%
train.shape
# Out:
# (131662, 14)

# %%
test.shape
# Out:
# (87395, 13)

# %%
df = train.append(test)

# %%
df.shape
# Out:
# (219057, 14)

# %%
df.head()
# Out:
#        Trip_ID  Trip_Distance Type_of_Cab  Customer_Since_Months  \
# 0  T0005689460           6.77           B                    1.0
# 1  T0005689461          29.47           B                   10.0
# 2  T0005689464          41.58         NaN                   10.0
# 3  T0005689465          61.56           C                   10.0
# 4  T0005689467          54.95           C                   10.0
#
#    Life_Style_Index Confidence_Life_Style_Index Destination_Type  \
# 0           2.42769                           A                A
# 1           2.78245                           B                A
# 2               NaN                         NaN                E
# 3               NaN                         NaN                A
# 4           3.03453                           B                A
#
#    Customer_Rating  Cancellation_Last_1Month  Var1  Var2  Var3  Gender  \
# 0          3.90500                         0  40.0    46    60  Female
# ...

# %%
df.tail()
# Out:
#            Trip_ID  Trip_Distance Type_of_Cab  Customer_Since_Months  \
# 87390  T0005908503          29.43           C                    3.0
# 87391  T0005908504          14.83           C                   10.0
# 87392  T0005908505          37.86           A                    6.0
# 87393  T0005908511          10.63           C                    1.0
# 87394  T0005908515          37.96           B                   10.0
#
#        Life_Style_Index Confidence_Life_Style_Index Destination_Type  \
# 87390           2.40720                           C                A
# 87391           2.57009                           A                D
# 87392           3.08227                           C                A
# 87393               NaN                         NaN                J
# 87394           3.00274                           A                A
#
#        Customer_Rating  Cancellation_Last_1Month   Var1  Var2  Var3  Gender  \
# ...

# %%
df.isna().sum()
# Out:
# Trip_ID                             0
# Trip_Distance                       0
# Type_of_Cab                     33368
# Customer_Since_Months            9886
# Life_Style_Index                33520
# Confidence_Life_Style_Index     33520
# Destination_Type                    0
# Customer_Rating                     0
# Cancellation_Last_1Month            0
# Var1                           117819
# Var2                                0
# Var3                                0
# Gender                              0
# Surge_Pricing_Type              87395
# dtype: int64

# %%
 # df[['Life_Style_Index','Confidence_Life_Style_Index']].head()
# df_temp1 =df[['Life_Style_Index','Confidence_Life_Style_Index']]
# df_temp1.head(2)
# df_temp1[df_temp1.isna().any(axis=1)]

# %% [markdown]
# ## Customer_Since_Months

# %%
df['Customer_Since_Months'].head()
# Out:
# 0     1.0
# 1    10.0
# 2    10.0
# 3    10.0
# 4    10.0
# Name: Customer_Since_Months, dtype: float64

# %%
df['Customer_Since_Months'].value_counts().sort_index().plot(kind = 'bar')

# %% [markdown]
# ## Customer_Since_Months & Type_of_cab

# %%
df_temp2 = df[df['Customer_Since_Months'] != 10.0]

# %%
df_temp2.head()
# Out:
#         Trip_ID  Trip_Distance Type_of_Cab  Customer_Since_Months  \
# 0   T0005689460           6.77           B                    1.0
# 7   T0005689472          18.44           B                    2.0
# 8   T0005689473         106.80           C                    3.0
# 9   T0005689474         107.19           D                    5.0
# 11  T0005689477          90.93         NaN                    0.0
#
#     Life_Style_Index Confidence_Life_Style_Index Destination_Type  \
# 0            2.42769                           A                A
# 7            2.81871                           B                A
# 8                NaN                         NaN                A
# 9            3.04467                           B                A
# 11           2.95327                           C                C
#
#     Customer_Rating  Cancellation_Last_1Month   Var1  Var2  Var3  Gender  \
# 0           3.90500                         0   40.0    46    60  Female
# ...

# %%
sns.countplot(x='Type_of_Cab',data=df_temp2,label='count')

# %%
df['Type_of_Cab'].value_counts().sort_index().plot(kind = 'bar')

# %%
#sns.pairplot(cd, x_vars= ('chocolate','fruity','caramel','peanutyalmondy'), y_vars='winpercent',size=7,aspect=0.7,kind='reg')

# %%
sns.barplot(x=df['Type_of_Cab'], y=df['Customer_Since_Months'])

# %%
sns.barplot(x=df['Destination_Type'], y=df['Customer_Since_Months'])

# %%
sns.barplot(x=df['Type_of_Cab'], y=df['Trip_Distance'])

# %%
df[df['Customer_Since_Months'].isna()].head(10)
# Out:
#          Trip_ID  Trip_Distance Type_of_Cab  Customer_Since_Months  \
# 13   T0005689482          31.16           B                    NaN
# 18   T0005689491          13.94           B                    NaN
# 35   T0005689515          36.10           B                    NaN
# 69   T0005689566          78.98           D                    NaN
# 107  T0005689632          21.46           B                    NaN
# 119  T0005689655          30.34           E                    NaN
# 140  T0005689687          13.85           D                    NaN
# 142  T0005689690          21.00           C                    NaN
# 152  T0005689705          13.32         NaN                    NaN
# 167  T0005689734          26.01           A                    NaN
#
#      Life_Style_Index Confidence_Life_Style_Index Destination_Type  \
# 13            2.69170                           B                A
# 18            2.35974                           B                B
# ...

# %%
sns.distplot(df['Trip_Distance'],hist=True)

# %%
df_temp1 = df[df['Trip_Distance'] < 40]

# %%
df_temp1.head()
# Out:
#        Trip_ID  Trip_Distance Type_of_Cab  Customer_Since_Months  \
# 0  T0005689460           6.77           B                    1.0
# 1  T0005689461          29.47           B                   10.0
# 5  T0005689469          19.06           E                   10.0
# 6  T0005689470          29.72           E                   10.0
# 7  T0005689472          18.44           B                    2.0
#
#    Life_Style_Index Confidence_Life_Style_Index Destination_Type  \
# 0           2.42769                           A                A
# 1           2.78245                           B                A
# 5               NaN                         NaN                A
# 6           2.83958                           C                B
# 7           2.81871                           B                A
#
#    Customer_Rating  Cancellation_Last_1Month   Var1  Var2  Var3  Gender  \
# 0           3.9050                         0   40.0    46    60  Female
# ...

# %%
df_temp1['Type_of_Cab'].value_counts().sort_index().plot(kind='bar')

# %%
df['Destination_Type'].value_counts().sort_index().plot(kind='bar')

# %% [markdown]
# ## Gender,Confidence_Life_Style_Index,Destination_Type & Type_of_Cab

# %%
sns.countplot(x='Type_of_Cab',data=df,hue='Gender')

# %%
sns.countplot(x='Confidence_Life_Style_Index',data=df,hue='Gender')

# %%
sns.countplot(x='Destination_Type',data=df,hue='Gender')

# %%
sns.countplot(x='Destination_Type',data=df,hue='Type_of_Cab')

# %%
#df_temp3 = df[(df['Destination_Type'] == 'A') & (df['Customer_Since_Months'] == 10.0)]

# %%
df['Confidence_Life_Style_Index'].value_counts().sort_index().plot.bar()

# %%
sns.countplot(x='Type_of_Cab',data=df,hue='Confidence_Life_Style_Index',orient ='h')

# %%
sns.countplot(x='Customer_Since_Months',data=df,hue='Confidence_Life_Style_Index',orient ='h')

# %%
sns.distplot(df['Life_Style_Index'],hist=True)

# %%
sns.boxplot(x='Life_Style_Index',data=df,hue='Confidence_Life_Style_Index')

# %%
df.groupby('Confidence_Life_Style_Index', as_index=False).agg({"Life_Style_Index": ['min','max']})
# Out:
#   Confidence_Life_Style_Index Life_Style_Index
#                                            min      max
# 0                           A          1.59638  4.69012
# 1                           B          1.31785  4.87511
# 2                           C          1.68789  4.87192

# %%
sns.lmplot(x='Life_Style_Index',y='Customer_Rating',data=df.sample(1000),fit_reg=True,markers="o",palette='Blues-d')

# %%
sns.lmplot(x='Trip_Distance',y='Customer_Rating',data=df.sample(1000),fit_reg=True,markers="o",palette='Blues-d')

# %%
sns.lmplot(x='Life_Style_Index',y='Trip_Distance',data=df.sample(500),fit_reg=True,markers="o",palette='Blues-d')

# %%
sns.pairplot(df.sample(500), x_vars= ('Var2','Var3','Customer_Rating','Trip_Distance'), y_vars='Life_Style_Index',height=7,aspect=0.7,kind='reg')

# %% [markdown]
# ## Surge_price_Type vs Rest Cat var

# %%
sns.countplot(x='Type_of_Cab',data=df,hue='Surge_Pricing_Type')

# %%
sns.countplot(x='Customer_Since_Months',data=df,hue='Surge_Pricing_Type')

# %%
sns.countplot(x='Confidence_Life_Style_Index',data=df,hue='Surge_Pricing_Type')

# %% [markdown]
# ## Cancellation vs Type_of_Cab

# %%
sns.countplot(x='Cancellation_Last_1Month',data=df.sample(2000),hue='Type_of_Cab')
